# %% [markdown]
# ![Maastricht_University_logo.svg](data:image/svg+xml;base64,...)
#
# # Information Retrieval and Text Mining Course - Neural Reranking Tutorial
# Authors: Abderrahmane Issam and Jan Scholtes
#
# Version 2024-2025
#
# #Notebook 4
#
# In this notebook we will learn how to use [Pyterrier](https://github.com/terrier-org/pyterrier), a Python framework that is built on top of the Java-based Terrier IR platform. Pyterrier can be used to index different formats of datasets and can be integrated with different models starting from classical approaches like BM25 up to neural models like ColBERT. We will learn how to use Pyterrier for indexing, search and evaluation.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### If you have a local GPU (Do the following steps in your local env):
# If you have a GPU and you want to run this notebook locally, then I suggest you set up a conda environement as follows:
#
#
#
# ```
# conda create --name ir python=3.11.1 \\
# conda install -c conda-forge openjdk=11 \\
# pip install notebook
# ```
# The second step is to start jupyter in your local machine as follows:
# ```
# jupyter notebook \
#     --NotebookApp.allow_origin='https://colab.research.google.com' \
#     --port=8888 \
#     --NotebookApp.port_retries=0
# ```
# Then go to `connect to local runtime` (which you will find in the menu where you can change the runtime) and paste the jupter backend URL that tou got in the output of the previous command.

# %% [markdown]
# If you are running this locally, then you only need to install packages once, otherwise, you will need to install them at the start of the instance and restart the runtime when required to.

# %%
# !pip install python-terrier
# Out:
# Requirement already satisfied: python-terrier in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.5.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from python-terrier) (10.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from python-terrier) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from python-terrier) (2.32.3)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.5.10)
# Requirement already satisfied: wget in /usr/local/lib/python3.11/dist-packages (from python-terrier) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.2.18)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.14.1)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.5.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (3.1.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.14.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.3.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: chest in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (4.4.4)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.13.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (5.3.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: pyarrow>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (18.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (2025.1.31)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.11/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->python-terrier) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->python-terrier) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2022.7.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier) (21.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (4.13.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from packaging>=21.3->statsmodels->python-terrier) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas->python-terrier) (1.17.0)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)

# %%
# !pip install --upgrade "git+https://github.com/terrierteam/pyterrier_colbert.git" --use-pep517
# Out:
# Collecting git+https://github.com/terrierteam/pyterrier_colbert.git
#   Cloning https://github.com/terrierteam/pyterrier_colbert.git to /tmp/pip-req-build-cv_jw71i
#   Running command git clone --filter=blob:none --quiet https://github.com/terrierteam/pyterrier_colbert.git /tmp/pip-req-build-cv_jw71i
#   Resolved https://github.com/terrierteam/pyterrier_colbert.git to commit ba5c86c0bc8da450dee361140541f35b5349a492
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT (from pyterrier-colbert==0.0.1)
#   Cloning https://github.com/cmacdonald/ColBERT.git (to revision v0.2) to /tmp/pip-install-m897m0wf/colbert_6164123c10f4485bb154d356c22b189a
#   Running command git clone --filter=blob:none --quiet https://github.com/cmacdonald/ColBERT.git /tmp/pip-install-m897m0wf/colbert_6164123c10f4485bb154d356c22b189a
#   Running command git checkout -b v0.2 --track origin/v0.2
#   Switched to a new branch 'v0.2'
#   Branch 'v0.2' set up to track remote branch 'v0.2' from 'origin'.
#   Resolved https://github.com/cmacdonald/ColBERT.git to commit ec191156d9c18f9f057103d3f2c9576c3eba2595
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-terrier>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from pyterrier-colbert==0.0.1) (0.13.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pyterrier-colbert==0.0.1) (1.5.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from pyterrier-colbert==0.0.1) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from pyterrier-colbert==0.0.1) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.26.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (10.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.32.3)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.5.10)
# Requirement already satisfied: wget in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.6.1)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.2.18)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.14.1)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.5.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.1.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.14.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.3.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.4.2)
# Requirement already satisfied: chest in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.3)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (4.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->pyterrier-colbert==0.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->pyterrier-colbert==0.0.1) (1.3.0)
# Requirement already satisfied: transformers<5,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (4.51.1)
# Requirement already satisfied: ujson in /usr/local/lib/python3.11/dist-packages (from ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (5.10.0)
# Requirement already satisfied: mlflow<=2.5 in /usr/local/lib/python3.11/dist-packages (from ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.30.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pyterrier-colbert==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pyterrier-colbert==0.0.1) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pyterrier-colbert==0.0.1) (3.6.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (4.13.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (5.3.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (6.0.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.6)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (0.2.3)
# Requirement already satisfied: pyarrow>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (18.1.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (8.1.8)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.2.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.18.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.1.44)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (4.25.6)
# Requirement already satisfied: packaging<22 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (21.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (5.2.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.5.3)
# Requirement already satisfied: alembic<2 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.15.2)
# Requirement already satisfied: docker<7,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (6.1.3)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.3.3)
# Requirement already satisfied: prometheus-flask-exporter<1 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.23.2)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.2.4)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.4.54)
# Requirement already satisfied: gunicorn<21 in /usr/local/lib/python3.11/dist-packages (from mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (20.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas->pyterrier-colbert==0.0.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2025.1.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.30.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=3.0.2->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.5.3)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.11/dist-packages (from chest->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (3.0.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.1.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic<2->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (2.6)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.10.1)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.9.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from docker<7,>=4.0.0->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.8.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=2.1.0->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.21.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from packaging<22->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.2.3)
# Requirement already satisfied: prometheus_client in /usr/local/lib/python3.11/dist-packages (from prometheus-flask-exporter<1->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (0.21.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<2,>=1.4.0->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (3.1.1)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.9.1->pyterrier-colbert==0.0.1) (1.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow<=2.5->ColBERT@ git+https://github.com/cmacdonald/ColBERT.git@v0.2#egg=ColBERT->pyterrier-colbert==0.0.1) (5.0.2)

# %% [markdown]
# ## Indexing and Search Using Pyterrier

# %%
# !pip install faiss-gpu-cu12

import faiss
assert faiss.get_num_gpus() > 0
# Out:
# Requirement already satisfied: faiss-gpu-cu12 in /usr/local/lib/python3.11/dist-packages (1.10.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (21.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from faiss-gpu-cu12) (12.4.5.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from packaging->faiss-gpu-cu12) (3.2.3)

# %%
# !pip install numpy --upgrade --force-reinstall

# %%
import pyterrier as pt
if not pt.java.started():
    pt.init()
# Out:
# terrier-assemblies 5.11 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# <ipython-input-4-10f47eda998d>:3: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# java is now started automatically with default settings. To force initialisation early, run:
# pt.java.init() # optional, forces java initialisation
#   pt.init()

# %% [markdown]
# Pyterrier can create an index from different dataset formats including Pandas DataFrame which we demonstrate below. We will create a synthetic DataFrame of documents, as well as queries and qrels to use for evaluation. After indexing the documents, we create a BM25 model that we will use for search later.

# %%
import pandas as pd

# 1. Define Documents
documents = pd.DataFrame([
    {"docno": "d1", "text": "PyTerrier is great for information retrieval."},
    {"docno": "d2", "text": "Terrier is a powerful information retrieval platform."},
    {"docno": "d3", "text": "Python is a popular programming language."},
    {"docno": "d4", "text": "This tutorial introduces PyTerrier basics."}
])

# 2. Define Queries
queries = pd.DataFrame([
    {"query": "information retrieval", "qid": "q1"},
    {"query": "programming tutorial", "qid": "q2"}
])

# 3. Define Relevance Judgments (qrels)
qrels = pd.DataFrame([
    {"qid": "q1", "docno": "d1", "label": 1},
    {"qid": "q1", "docno": "d2", "label": 0},
    {"qid": "q2", "docno": "d3", "label": 1},
    {"qid": "q2", "docno": "d4", "label": 1}
])

# 4. Indexing
index_path = "./index"
# !rm -r "./index"    # Remove index if it exists

indexer = pt.index.DFIndexer(index_path)
index_ref = indexer.index(text=documents["text"], docno=documents["docno"])

# 5. Retrieval (BM25)
bm25 = pt.BatchRetrieve(index_ref, wmodel="BM25")
# Out:
# rm: cannot remove './index': No such file or directory
# <ipython-input-5-83e90585fa44>:29: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.index.DFIndexer(index_path)
# <ipython-input-5-83e90585fa44>:33: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index_ref, wmodel="BM25")

# %% [markdown]
# We can see the files were created:

# %%
# !ls -ltrh ./index
# Out:
# total 44K
# -rw-r--r-- 1 root root    7 Apr 15 21:44 data.direct.bf
# -rw-r--r-- 1 root root   64 Apr 15 21:44 data.meta.zdata
# -rw-r--r-- 1 root root   32 Apr 15 21:44 data.meta.idx
# -rw-r--r-- 1 root root   68 Apr 15 21:44 data.document.fsarrayfile
# -rw-r--r-- 1 root root   44 Apr 15 21:44 data.meta-0.fsomapfile
# -rw-r--r-- 1 root root    9 Apr 15 21:44 data.inverted.bf
# -rw-r--r-- 1 root root 1.1K Apr 15 21:44 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root   52 Apr 15 21:44 data.lexicon.fsomapid
# -rw-r--r-- 1 root root  321 Apr 15 21:44 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root 4.1K Apr 15 21:44 data.properties

# %% [markdown]
# We can see statistics of our index as follows:

# %%
index = pt.IndexFactory.of(index_ref)
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 4
# Number of terms: 13
# Number of postings: 15
# Number of fields: 0
# Number of tokens: 15
# Field names: []
# Positions:   false

# %%
terms = index.getLexicon()

for entry in terms:
    print(entry.getKey())
# Out:
# basic
# great
# introduc
# languag
# platform
# popular
# power
# program
# pyterri
# python
# retriev
# terrier
# tutori

# %% [markdown]
# ### Exercise 1:
# The number of terms (13) is less than the number of words in all the 4 documents. Explain the reason for this.

# %% [markdown]
# Answer here

# %% [markdown]
# These are the terms identified by Pyterrier.

# %%
for kv in index.getLexicon():
  print("%s -> %s" % (kv.getKey(), kv.getValue().toString() ) )
# Out:
# basic -> term11 Nt=1 TF=1 maxTF=1 @{0 0 0}
# great -> term2 Nt=1 TF=1 maxTF=1 @{0 0 6}
# introduc -> term12 Nt=1 TF=1 maxTF=1 @{0 1 0}
# languag -> term6 Nt=1 TF=1 maxTF=1 @{0 1 6}
# platform -> term4 Nt=1 TF=1 maxTF=1 @{0 2 2}
# popular -> term8 Nt=1 TF=1 maxTF=1 @{0 2 6}
# power -> term3 Nt=1 TF=1 maxTF=1 @{0 3 2}
# program -> term9 Nt=1 TF=1 maxTF=1 @{0 3 6}
# pyterri -> term1 Nt=2 TF=2 maxTF=1 @{0 4 2}
# python -> term7 Nt=1 TF=1 maxTF=1 @{0 5 0}
# retriev -> term0 Nt=2 TF=2 maxTF=1 @{0 5 4}
# terrier -> term5 Nt=1 TF=1 maxTF=1 @{0 6 0}
# tutori -> term10 Nt=1 TF=1 maxTF=1 @{0 6 4}

# %% [markdown]
# We can search a Pyterrier index using BM25 with the following function:

# %%
bm25.search("programming language")
# Out:
#   qid  docid docno  rank     score                 query
# 0   1      2    d3     0  2.379879  programming language

# %% [markdown]
# ### Exercise2
#
# Define each column in the output of search above.

# %% [markdown]
# Answer here.

# %% [markdown]
# Pyterrier offers a way to evaluate models using a different metrics. The list of possible metrics to use is available here: https://pyterrier.readthedocs.io/en/latest/experiments.html#evaluation-measures-objects. \\
#
# We can also see how `Experiment` accepts a DataFrame of queries and qrels which are used to compute the metrics.

# %%
# 6. Evaluation Pipeline
pt.Experiment([bm25], queries, qrels, eval_metrics=["map", "P_10"], names=["BM25"])
# Out:
#    name   map  P_10
# 0  BM25  0.75  0.15

# %% [markdown]
# ### Exercise 3
#
# Instead of BM25 use a TF_IDF model. Try using it to search for a query then pass it along with bm25 to `Experiment`.

# %%
# Answer here

# %% [markdown]
# ## Neural Reranking with ColBERT

# %% [markdown]
# Below we use `pyterrier_colbert` which is a plugin for Pyterrier that makes it possible to use a ColBERT model for indexing and retrieval. We will use the [Vaswani NPL corpus](http://ir.dcs.gla.ac.uk/resources/test_collections/npl/), a corpus of 11,429 scientific abstract, with corresponding queries and relevance assessments.

# %%
# !rm -rf ./colbertindex

import pyterrier_colbert.indexing

checkpoint="http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip"

indexer = pyterrier_colbert.indexing.ColBERTIndexer(checkpoint, "./", "colbertindex", chunksize=3)
indexer.index(pt.get_dataset("irds:vaswani").get_corpus_iter())
# Out:
# vaswani documents:   0%|          | 0/11429 [00:00<?, ?it/s]
# [Apr 15, 21:47:22] [0] 		 #> Local args.bsize = 128
# [Apr 15, 21:47:22] [0] 		 #> args.index_root = ./
# [Apr 15, 21:47:22] [0] 		 #> self.possible_subset_sizes = [69905]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of ColBERT were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['linear.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Apr 15, 21:47:26] #> Loading model checkpoint.
# [Apr 15, 21:47:26] #> Loading checkpoint http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip
# Downloading: "http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip" to /root/.cache/torch/hub/checkpoints/colbert.dnn.zip
#
#   0%|          | 0.00/1.11G [00:00<?, ?B/s]
#   0%|          | 128k/1.11G [00:00<1:21:08, 244kB/s]
#   0%|          | 256k/1.11G [00:00<49:23, 401kB/s]
#   0%|          | 384k/1.11G [00:00<33:54, 584kB/s]
#   0%|          | 768k/1.11G [00:01<17:26, 1.13MB/s]
#   0%|          | 1.38M/1.11G [00:01<08:55, 2.21MB/s]
#   0%|          | 1.88M/1.11G [00:01<07:24, 2.67MB/s]
#   0%|          | 2.88M/1.11G [00:01<04:26, 4.44MB/s]
#   0%|          | 5.50M/1.11G [00:01<02:01, 9.70MB/s]
#   1%|          | 6.62M/1.11G [00:01<02:07, 9.24MB/s]
#   1%|          | 8.75M/1.11G [00:01<01:35, 12.3MB/s]
#   1%|          | 12.0M/1.11G [00:01<01:05, 17.9MB/s]
#   1%|          | 14.0M/1.11G [00:01<01:03, 18.6MB/s]
#  89%|████████▉ | 0.98G/1.11G [00:59<00:06, 20.5MB/s]
#  89%|████████▉ | 0.99G/1.11G [00:59<00:06, 18.7MB/s]
#  89%|████████▉ | 0.99G/1.11G [01:00<00:05, 20.9MB/s]
#  90%|████████▉ | 0.99G/1.11G [01:00<00:05, 20.8MB/s]
#  90%|████████▉ | 0.99G/1.11G [01:00<00:06, 18.8MB/s]
#  90%|█████████ | 1.00G/1.11G [01:00<00:06, 18.4MB/s]
#  90%|█████████ | 1.00G/1.11G [01:00<00:05, 19.2MB/s]
#  91%|█████████ | 1.00G/1.11G [01:00<00:05, 19.7MB/s]
#  91%|█████████ | 1.01G/1.11G [01:01<00:05, 20.0MB/s]
#  91%|█████████▏| 1.01G/1.11G [01:01<00:05, 20.2MB/s]
#  92%|█████████▏| 1.02G/1.11G [01:01<00:04, 20.7MB/s]
#  92%|█████████▏| 1.02G/1.11G [01:01<00:04, 20.3MB/s]
#  92%|█████████▏| 1.02G/1.11G [01:01<00:04, 20.4MB/s]
#  93%|█████████▎| 1.03G/1.11G [01:01<00:04, 20.5MB/s]
#  93%|█████████▎| 1.03G/1.11G [01:02<00:03, 20.7MB/s]
#  93%|█████████▎| 1.03G/1.11G [01:02<00:03, 20.8MB/s]
#  94%|█████████▍| 1.04G/1.11G [01:02<00:03, 21.1MB/s]
#  94%|█████████▍| 1.04G/1.11G [01:02<00:03, 20.7MB/s]
#  94%|█████████▍| 1.05G/1.11G [01:02<00:03, 20.8MB/s]
#  95%|█████████▍| 1.05G/1.11G [01:03<00:02, 20.7MB/s]
#  95%|█████████▌| 1.05G/1.11G [01:03<00:02, 20.9MB/s]
#  95%|█████████▌| 1.06G/1.11G [01:03<00:02, 20.8MB/s]
#  96%|█████████▌| 1.06G/1.11G [01:03<00:02, 20.9MB/s]
#  96%|█████████▌| 1.06G/1.11G [01:03<00:02, 20.9MB/s]
#  97%|█████████▋| 1.07G/1.11G [01:04<00:01, 20.8MB/s]
#  97%|█████████▋| 1.07G/1.11G [01:04<00:01, 20.9MB/s]
#  97%|█████████▋| 1.08G/1.11G [01:04<00:01, 20.9MB/s]
#  98%|█████████▊| 1.08G/1.11G [01:04<00:01, 20.8MB/s]
#  98%|█████████▊| 1.08G/1.11G [01:04<00:01, 20.9MB/s]
#  98%|█████████▊| 1.09G/1.11G [01:05<00:01, 20.8MB/s]
#  99%|█████████▊| 1.09G/1.11G [01:05<00:00, 20.9MB/s]
#  99%|█████████▉| 1.09G/1.11G [01:05<00:00, 20.9MB/s]
#  99%|█████████▉| 1.10G/1.11G [01:05<00:00, 21.0MB/s]
# 100%|█████████▉| 1.10G/1.11G [01:05<00:00, 20.8MB/s]
# 100%|██████████| 1.11G/1.11G [01:06<00:00, 18.0MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/hub.py:870: FutureWarning: Falling back to the old format < 1.6. This support will be deprecated in favor of default zipfile format introduced in 1.6. Please redo torch.save() to save it in the new zipfile format.
#   return _legacy_zip_load(cached_file, model_dir, map_location, weights_only)
# [Apr 15, 21:48:46] #> checkpoint['epoch'] = 0
# [Apr 15, 21:48:46] #> checkpoint['batch'] = 44500
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [Apr 15, 21:48:49] #> Note: Output directory ./ already exists
#
#
#
#
# [Apr 15, 21:48:49] #> Creating directory ./colbertindex
# [INFO] [starting] http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz
#
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 0.0%| 0.00/2.13M [00:00<?, ?B/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 0.8%| 16.4k/2.13M [00:00<00:23, 91.3kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 2.3%| 49.2k/2.13M [00:00<00:15, 135kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 3.9%| 81.9k/2.13M [00:00<00:13, 150kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 7.3%| 156k/2.13M [00:00<00:09, 213kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 14.6%| 311k/2.13M [00:00<00:05, 341kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 29.7%| 631k/2.13M [00:01<00:02, 576kB/s]
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: 59.0%| 1.25M/2.13M [00:01<00:00, 980kB/s]
# [INFO] [finished] http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: [00:01] [2.13MB] [1.64MB/s]
#
# http://ir.dcs.gla.ac.uk/resources/test_collections/npl/npl.tar.gz: [00:01] [2.13MB] [1.64MB/s]
# [Apr 15, 21:50:40] [0] 		 #> Completed batch #0 (starting at passage #0) 		Passages/min: 6.2k (overall),  6.3k (this encoding),  18089.3M (this saving)
# [Apr 15, 21:50:40] [0] 		 [NOTE] Done with local share.
# [Apr 15, 21:50:40] [0] 		 #> Joining saver thread.
# [Apr 15, 21:50:40] [0] 		 #> Saved batch #0 to ./colbertindex/0.pt 		 Saving Throughput = 2.4M passages per minute.
#
# #> num_embeddings = 581496
# [Apr 15, 21:50:40] #> Starting..
# [Apr 15, 21:50:40] #> Processing slice #1 of 1 (range 0..1).
# [Apr 15, 21:50:40] #> Will write to ./colbertindex/ivfpq.100.faiss.
# [Apr 15, 21:50:40] #> Loading ./colbertindex/0.sample ...
# #> Sample has shape (29074, 128)
# [Apr 15, 21:50:40] Preparing resources for 1 GPUs.
# [Apr 15, 21:50:40] #> Training with the vectors...
# [Apr 15, 21:50:40] #> Training now (using 1 GPUs)...
# 0.17531108856201172
# 11.137163639068604
# 0.008240699768066406
# [Apr 15, 21:50:52] Done training!
#
# [Apr 15, 21:50:52] #> Indexing the vectors...
# [Apr 15, 21:50:52] #> Loading ('./colbertindex/0.pt', None, None) (from queue)...
# [Apr 15, 21:50:52] #> Processing a sub_collection with shape (581496, 128)
# [Apr 15, 21:50:52] Add data with shape (581496, 128) (offset = 0)..
# 524288/581496 (0.410 s)   Flush indexes to CPU
# add(.) time: 0.468 s 		--		 index.ntotal = 581496
# [Apr 15, 21:50:53] Done indexing!
# [Apr 15, 21:50:53] Writing index to ./colbertindex/ivfpq.100.faiss ...
# [Apr 15, 21:50:53]
#
# Done! All complete (for slice #1 of 1)!
# #> Faiss encoding complete
# #> Indexing complete, Time elapsed 210.73 seconds

# %%
# !ls -ltrh ./colbertindex
# Out:
# total 168M
# -rw-r--r-- 1 root root 142M Apr 15 21:50 0.pt
# -rw-r--r-- 1 root root 4.5M Apr 15 21:50 0.tokenids
# -rw-r--r-- 1 root root 7.1M Apr 15 21:50 0.sample
# -rw-r--r-- 1 root root  35K Apr 15 21:50 doclens.0.json
# -rw-r--r-- 1 root root  24K Apr 15 21:50 docnos.pkl.gz
# -rw-r--r-- 1 root root  14M Apr 15 21:50 ivfpq.100.faiss

# %%
pyterrier_colbert_factory = indexer.ranking_factory()

colbert_e2e = pyterrier_colbert_factory.end_to_end()
# Out:
# [Apr 15, 21:51:02] #> Loading the FAISS index from ./colbertindex/ivfpq.100.faiss ..
# [Apr 15, 21:51:02] #> Building the emb2pid mapping..
# [Apr 15, 21:51:02] len(self.emb2pid) = 581496
# /usr/local/lib/python3.11/dist-packages/colbert/utils/amp.py:14: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
# Loading reranking index, memtype=mem
# Loading index shards to memory:   0%|          | 0/1 [00:00<?, ?shard/s]

# %% [markdown]
# We search using ColBERT as follows. `% 5` is used to retrieve the top 5 most relevant entries.

# %%
out = (colbert_e2e % 5).search("chemical reactions")
out
# Out:
# /usr/local/lib/python3.11/dist-packages/colbert/utils/amp.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   return torch.cuda.amp.autocast() if self.activated else nullcontext()
#   qid               query  docid  \
# 0   1  chemical reactions   4911
# 3   1  chemical reactions   7048
# 2   1  chemical reactions   6479
# 4   1  chemical reactions   9373
# 1   1  chemical reactions   6278
#
#                                           query_toks  \
# 0  [tensor(101), tensor(1), tensor(5072), tensor(...
# 3  [tensor(101), tensor(1), tensor(5072), tensor(...
# 2  [tensor(101), tensor(1), tensor(5072), tensor(...
# 4  [tensor(101), tensor(1), tensor(5072), tensor(...
# 1  [tensor(101), tensor(1), tensor(5072), tensor(...
#
#                                           query_embs      score docno  rank
# 0  [[tensor(0.0680), tensor(-0.0085), tensor(0.11...  19.821638  4912     0
# 3  [[tensor(0.0680), tensor(-0.0085), tensor(0.11...  19.053555  7049     1
# 2  [[tensor(0.0680), tensor(-0.0085), tensor(0.11...  18.036415  6480     2
# 4  [[tensor(0.0680), tensor(-0.0085), tensor(0.11...  17.136055  9374     3
# 1  [[tensor(0.0680), tensor(-0.0085), tensor(0.11...  16.793301  6279     4

# %%
out.loc[0, 'query_toks']
# Out:
# tensor([ 101,    1, 5072, 9597,  102,  103,  103,  103,  103,  103,  103,  103,
#          103,  103,  103,  103,  103,  103,  103,  103,  103,  103,  103,  103,
#          103,  103,  103,  103,  103,  103,  103,  103])

# %%
out.loc[0, 'query_embs'].shape
# Out:
# torch.Size([32, 128])

# %% [markdown]
# ### Exercise 4
#
# There are two new columns in the search results: `query_toks` and `query_embs`. Explain what they are and explain the shape of `query_embs`.

# %% [markdown]
# Answer here.

# %%
dataset = pt.datasets.get_dataset("vaswani")
index_path = "./index"

# !rm -rf ./index
indexer = pt.TRECCollectionIndexer(index_path)

indexer = indexer.index(dataset.get_corpus())

bm25 = pt.BatchRetrieve(indexer, wmodel="BM25")
# Out:
# Downloading vaswani corpus to /root/.pyterrier/corpora/vaswani/corpus
# doc-text.trec:   0%|          | 0.00/0.99M [00:00<?, ?iB/s]
# <ipython-input-18-fbd34d1729a5>:9: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(indexer, wmodel="BM25")

# %% [markdown]
# In the following code we create a sentence transformer reranker.

# %%
import pandas as pd
from sentence_transformers import CrossEncoder

crossmodel = CrossEncoder('cross-encoder/ms-marco-TinyBERT-L-6', max_length=512)

def _crossencoder_apply(df : pd.DataFrame):
  return crossmodel.predict(list(zip(df['query'].values, df['text'].values)))

cross_encT = pt.apply.doc_score(_crossencoder_apply, batch_size=128)
# Out:
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# We create a reranking pipeline that starts with BM25 as a retriever, and ends with using a sentence transformer (cross_encT) for reranking the retrieved documents. The reranking step requires the document text as input, which is not returned by default by bm25, and that is why we add `pt.text.get_text(dataset, 'text')` to retrieve the text documents and add them to the output of BM25.

# %%
dataset = pt.get_dataset('irds:vaswani')
cross_enc_rerank = bm25 >> pt.text.get_text(dataset, 'text') >> cross_encT

# %%
out = (bm25 % 5).search("chemical reactions")
out
# Out:
#   qid  docid  docno  rank      score               query
# 0   1   9373   9374     0  22.076426  chemical reactions
# 1   1   8765   8766     1  20.498801  chemical reactions
# 2   1   7048   7049     2  20.159044  chemical reactions
# 3   1   4686   4687     3  19.323491  chemical reactions
# 4   1  10702  10703     4  13.472012  chemical reactions

# %%
out = (cross_enc_rerank % 5).search("chemical reactions")
out
# Out:
# [INFO] [starting] building docstore
# docs_iter: 100%|██████████████████████| 11429/11429 [00:00<00:00, 38612.82doc/s]
# [INFO] [finished] docs_iter: [00:00] [11429doc] [38122.15doc/s]
# [INFO] [finished] building docstore s]
#   qid  docid docno     score               query  \
# 1   1   7048  7049  0.004507  chemical reactions
# 0   1   9373  9374  0.000726  chemical reactions
# 3   1   6479  6480  0.000398  chemical reactions
# 2   1   4686  4687  0.000275  chemical reactions
# 4   1   8706  8707  0.000251  chemical reactions
#
#                                                 text  rank
# 1  some reactions occurring in the earths upper a...     0
# 0  ion neutral reactions  a list is given of reac...     1
# 3  reaction concept in electromagnetic theory  a ...     2
# 2  nitrogen oxides and the airglow  possible chem...     3
# 4  ion charge exchange reactions in oxygen afterg...     4

# %% [markdown]
# The following demonstrates how we can contruct IR pipelines using Pyterrier. The pipeline starts by using bm25 to retrieve relevant documents, which are then used by QueryExpantion transformer which expands the query by adding informative terms that are collected from the relevant documents. The last part runs bm25 with the new query. This process is called Pseudo Relevance Feedback (PRF).

# %%
query_expansion = bm25 >> pt.rewrite.QueryExpansion(indexer) >> bm25

# %%
pt.Experiment(
    [bm25, query_expansion, colbert_e2e, cross_enc_rerank],
    dataset.get_topics(),
    dataset.get_qrels(),
    eval_metrics=["map", "P_10", "mrt"],
    names = ["BM25", "QE", "ColBERT", "BM25 >> CrossEnc"]
)
# Out:
# 21:52:22.832 [main] WARN org.terrier.querying.QueryExpansion -- qemodel control not set for QueryExpansion post process. Using default model Bo1
# /usr/local/lib/python3.11/dist-packages/colbert/utils/amp.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   return torch.cuda.amp.autocast() if self.activated else nullcontext()
#                name       map      P_10          mrt
# 0              BM25  0.296517  0.352688    30.692147
# 1                QE  0.304647  0.369892    65.717505
# 2           ColBERT  0.278678  0.351613   611.180842
# 3  BM25 >> CrossEnc  0.275168  0.345161  4492.456365

# %% [markdown]
# On this small dataset, we can see that BM25 achieves better results than ColBERT. Adding Query Expansion improves MAP a little. But using PRF with ColBERT hurts (ColBERT-PRF) the performance while slowing down the inference because of the extra PRF step.

# %% [markdown]
# ### Exercise 5
#
# Apply the same process as above on a dataset of your choice. You can find the list of datasets in Pyterrier here: https://pyterrier.readthedocs.io/en/latest/datasets.html#available-datasets

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Add at least 2 other metrics and explain what each of them is trying to capture.

# %%
# Answer both exercise 5 and 6 here

# %% [markdown]
# ### Exercise 7
#
# Follow the example in this [README](https://github.com/terrierteam/pyterrier_colbert/tree/ba5c86c0bc8da450dee361140541f35b5349a492) to implement Pseudo Relevance Feedback (PRF) with ColBERT. Describe how it works, and add ColBERT-PRF to `Experiment` to evaluate it against the other pipelines.

# %%
# Answer here

# %% [markdown]
# ### Exercise 8
#
# Implement a reranking pipeline with ColBERT and add it to `Experiment`.

# %%
# Answer here

# %% [markdown]
# ## Arxiv Abstracts Retrieval

# %%
# !pip install setuptools==68.0.0       # you ca skip this if you are using a local instance
# Out:
# Collecting setuptools==68.0.0
#   Downloading setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading setuptools-68.0.0-py3-none-any.whl (804 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.0/804.0 kB 37.3 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# pandas-gbq 0.28.0 requires packaging>=22.0.0, but you have packaging 21.3 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed setuptools-68.0.0

# %%
# !pip install arxiv==2.1.3
# Out:
# Collecting arxiv==2.1.3
#   Downloading arxiv-2.1.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting feedparser~=6.0.10 (from arxiv==2.1.3)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests~=2.32.0 in /usr/local/lib/python3.11/dist-packages (from arxiv==2.1.3) (2.32.3)
# Collecting sgmllib3k (from feedparser~=6.0.10->arxiv==2.1.3)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.0->arxiv==2.1.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.0->arxiv==2.1.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.0->arxiv==2.1.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.0->arxiv==2.1.3) (2025.1.31)
# Downloading arxiv-2.1.3-py3-none-any.whl (11 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.5 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=ef2f15170c7255d83a47c169c6f72ab5c9f54984fa44eb110d6b35e58ddcdd2a
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, arxiv
# Successfully installed arxiv-2.1.3 feedparser-6.0.11 sgmllib3k-1.0.0

# %% [markdown]
# The following code will retrieve 1000 abstracts for the query "nlp".

# %%
import arxiv

# Search for papers
search = arxiv.Search(
    query="nlp",
    max_results=1000,
    sort_by=arxiv.SortCriterion.SubmittedDate
)

# %% [markdown]
# We construct a dictionary of titles and abstracts.

# %%
documents = []
for result in search.results():
    documents.append({
        'title': result.title,
        'abstract': result.summary,

    })
# Out:
# <ipython-input-28-c429ecc137a1>:2: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():

# %%
documents[0]
# Out:
# {'title': 'MorphTok: Morphologically Grounded Tokenization for Indian Languages',
#  'abstract': 'Tokenization is a crucial step in NLP, especially with the rise of large\nlanguage models (LLMs), impacting downstream performance, computational cost,\nand efficiency. Existing LLMs rely on the classical Byte-pair Encoding (BPE)\nalgorithm for subword tokenization that greedily merges frequent character\nbigrams. This often leads to segmentation that does not align with\nlinguistically meaningful units. To address this, we propose morphology-aware\nsegmentation as a pre-tokenization step prior to applying BPE. To facilitate\nmorphology-aware segmentation, we create a novel dataset for Hindi and Marathi,\nincorporating sandhi splitting to enhance the subword tokenization. Experiments\non downstream tasks show that morphologically grounded tokenization improves\nperformance for machine translation and language modeling. Additionally, to\nhandle the ambiguity in the Unicode characters for diacritics, particularly\ndependent vowels in syllable-based writing systems, we introduce Constrained\nBPE (CBPE), an extension to the traditional BPE algorithm that incorporates\nscript-specific constraints. Specifically, CBPE handles dependent vowels. Our\nresults show that CBPE achieves a 1.68\\% reduction in fertility scores while\nmaintaining comparable or improved downstream performance in machine\ntranslation, offering a computationally efficient alternative to standard BPE.\nMoreover, to evaluate segmentation across different tokenization algorithms, we\nintroduce a new human evaluation metric, \\textit{EvalTok}, enabling more\nhuman-grounded assessment.'}

# %% [markdown]
# Rerun this in case you had to restart the session.

# %%
import pyterrier as pt
if not pt.java.started():
    pt.init()

# %% [markdown]
# To create an index, we need to to have a docno field which we create below, and a text field which is the abstract in this case. \\
# We use `DFIndexer` which allows us to create by passing a list ids and text.

# %%
import pandas as pd

index_path = './arxivindex'
# !rm -r './arxivindex'

df = pd.DataFrame({
    'docno': ['doc'+str(i) for i in range(len(documents))],
    'text': [document['abstract'] for document in documents]
})

indexer = pt.DFIndexer(index_path)
indexer.index(docno=df.docno, text=df.text)
# Out:
# rm: cannot remove './arxivindex': No such file or directory
# <ipython-input-31-ca0207ece758>:11: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.DFIndexer(index_path)
# <org.terrier.querying.IndexRef at 0x7e57f49a0110 jclass=org/terrier/querying/IndexRef jself=<LocalRef obj=0x58a13b0 at 0x7e581ad0f7f0>>

# %% [markdown]
# We create a BM25 retrieval model for the Arxiv index.

# %%
bm25 = pt.BatchRetrieve(indexer, wmodel="BM25")
# Out:
# <ipython-input-32-a01c4b365fec>:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(indexer, wmodel="BM25")

# %%
(bm25 % 5).search("information retrieval")
# Out:
#   qid  docid   docno  rank     score                  query
# 0   1    842  doc842     0  6.634921  information retrieval
# 1   1    524  doc524     1  6.398256  information retrieval
# 2   1    926  doc926     2  6.297607  information retrieval
# 3   1     40   doc40     3  6.266992  information retrieval
# 4   1    192  doc192     4  6.264405  information retrieval

# %%
df[df['docno']=='doc670'].text.item()
# Out:
# "Evaluating the quality of machine-generated natural language content is a\nchallenging task in Natural Language Processing (NLP). Recently, large language\nmodels (LLMs) like GPT-4 have been employed for this purpose, but they are\ncomputationally expensive due to the extensive token usage required by complex\nevaluation prompts. In this paper, we propose a prompt optimization approach\nthat uses a smaller, fine-tuned language model to compress input data for\nevaluation prompt, thus reducing token usage and computational cost when using\nlarger LLMs for downstream evaluation. Our method involves a two-stage\nfine-tuning process: supervised fine-tuning followed by preference optimization\nto refine the model's outputs based on human preferences. We focus on Machine\nTranslation (MT) evaluation and utilize the GEMBA-MQM metric as a starting\npoint. Our results show a $2.37\\times$ reduction in token usage without any\nloss in evaluation quality. This work makes state-of-the-art LLM-based metrics\nlike GEMBA-MQM more cost-effective and efficient, enhancing their accessibility\nfor broader use."

# %% [markdown]
# ### Exercise 9
#
# Create a ColBERT index using the Arxiv documents retrieved above and use it to search for some queries. Try to highlight how it is different from BM25 through the query results. You can also change the query we used to get arxiv pages.
